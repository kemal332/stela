# %%
import numpy as np
import cv2
import pytesseract

cap = cv2.VideoCapture(0)

while cap.isOpened():
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    print(pytesseract.image_to_string(frame))

    # Display the resulting frame
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
# 7a ™
# eS \ L
# y 7
# 2
# a =
# ees.
#
# Pet
#
#
#
# 123 456
#
#
#
# de
#
#
#
# ‘Ve
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     509     try:
# --> 510         fh = fp.fileno()
#     511         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-756f394c2a3b> in <module>
#      11     # Our operations on the frame come here
#      12     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# ---> 13     print(pytesseract.image_to_string(frame))
#      14
#      15     # Display the resulting frame
#
# /usr/local/lib/python3.9/site-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     407     args = [image, 'txt', lang, config, nice, timeout]
#     408
# --> 409     return {
#     410         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     411         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#
# /usr/local/lib/python3.9/site-packages/pytesseract/pytesseract.py in <lambda>()
#     410         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     411         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 412         Output.STRING: lambda: run_and_get_output(*args),
#     413     }[output_type]()
#     414
#
# /usr/local/lib/python3.9/site-packages/pytesseract/pytesseract.py in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     274 ):
#     275
# --> 276     with save(image) as (temp_name, input_filename):
#     277         kwargs = {
#     278             'input_filename': input_filename,
#
# /usr/local/Cellar/python@3.9/3.9.2_2/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py in __enter__(self)
#     115         del self.args, self.kwds, self.func
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#     119             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.9/site-packages/pytesseract/pytesseract.py in save(image)
#     199             image, extension = prepare(image)
#     200             input_file_name = f.name + extsep + extension
# --> 201             image.save(input_file_name, format=image.format)
#     202             yield f.name, input_file_name
#     203     finally:
#
# /usr/local/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2149
#    2150         try:
# -> 2151             save_handler(self, fp, filename)
#    2152         finally:
#    2153             # do what we can to clean up
#
# /usr/local/lib/python3.9/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1337         _write_multiple_frames(im, fp, chunk, rawmode)
#    1338     else:
# -> 1339         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1340
#    1341     if info:
#
# /usr/local/lib/python3.9/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     522             else:
#     523                 while True:
# --> 524                     l, s, d = e.encode(bufsize)
#     525                     fp.write(d)
#     526                     if s:
#
# KeyboardInterrupt:
